# %%
def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(len(arr)-i-1):
            if arr[j]>arr[j+1]:
                arr[j+1],arr[j]=arr[j],arr[j+1]
    return arr

# %%
bubble_sort([13, 46, 24, 52, 20, 9])
# Out:
# [9, 13, 20, 24, 46, 52]

# %% [markdown]
# algorithm <br>
# step 1 initialise a loop starting from 0 to n-1 <br>
# step 2 initialise inner loop starting 0 from 0 to n-1-i <br>
# step 3 in the inner loop starting from the start compare elements adjacent elements <br>
# step 4 move the element with higher value to the last <br>

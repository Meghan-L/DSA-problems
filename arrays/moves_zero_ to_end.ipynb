# %%
def move_to_end(arr):
    res=[]
    count=0
    for i in arr:
        if i!=0:
            res.append(i)
        else:
            count+=1
    for i in range(count):
        res.append(0)

# %% [markdown]
# algorithm - time O(n) space O(n) <br>
# step 1 initialise a result array <br>
# step 2 add all the values that are not zero to result and count zeros <br>
# step 3 append the no of zeros at the end <br>

# %%
def move_zero(arr):
    k=0
    for i in arr:
        if i != 0 :
            arr[k]=i
            k+=1
    for i in range(k,len(nums)):
        arr[i]=0

# %% [markdown]
# algorithm - time O(n) and space O(1)<br>
# step 1 initialise a variable k <br>
# step 2 every time the value is not zero over write starting from index 0(k)<br>
# step 3 overwrite values starting from index k to n-1

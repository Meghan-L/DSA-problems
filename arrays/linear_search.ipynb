# %%
def linear_search(arr,target):
    for i in arr:
        if i == target:
            return True
    return False

# %% [markdown]
# algorithm - time O(n) space O(1) <br>
# step 1 starting from index 0 to n-1 <br>
# step 2 check whether each element is equal to target or not <br>
